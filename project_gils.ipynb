# %%
# IMPORTING
import pandas as pd


LK = pd.read_stata('fin07.dta')
pd.set_option('display.max_rows', 500)


# VARIABLE DROP
# DATA.drop(columns="VARIABLE")
LK.drop(columns="g3c")


# hahahihehohu
# Out:
#                 province commid07  gtype                type
# 0         SUMATERA UTARA     1205    1.0                 BRI
# 1         SUMATERA UTARA     1205    5.0   Other Formal Coop
# 2         SUMATERA UTARA     1205    6.0  State/private bank
# 3         SUMATERA UTARA     1205    2.0                 BPR
# 4         SUMATERA UTARA     1210    5.0   Other Formal Coop
# 5         SUMATERA UTARA     1214    1.0                 BRI
# 6         SUMATERA UTARA     1214    6.0  State/private bank
# 7         SUMATERA UTARA     1215    2.0                 BPR
# 8         SUMATERA UTARA     1215    1.0                 BRI
# 9         SUMATERA UTARA     1215    6.0  State/private bank
# 10        SUMATERA UTARA     1215    3.0                 LKD
# 11        SUMATERA UTARA     1218    4.0                 KUD
# 12        SUMATERA UTARA     1221    1.0                 BRI
# 13        SUMATERA UTARA     1222    1.0                 BRI
# ...

# %%
import pandas as pd
LL = pd.read_stata('LL_train.dta')
pd.set_option('display.max_rows',-1)
