# %%
from pandas import *
from numpy import *
from statsmodels.formula.api import *

indra_kereta=read_stata('LL_train.dta')
bekerja_ndewe=read_stata('self_employment.dta')
income_month=indra_kereta.income_month
#how to make natural logarithm#
log_income=log(income_month)
print ([log_income, income_month])
# Out:
# [0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6        13.772951
# 7        12.583366
# 8              NaN
# 9        12.048444
# 10             NaN
# 11       12.611538
# 12       13.247526
# 13             NaN
# 14             NaN
# 15       11.512925
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21       12.429216
# 22             NaN
# 23             NaN
# 24             NaN
# 25       14.209803
# 26             NaN
# 27             NaN
# 28       12.919839
# 29       14.220976
#            ...
# 22280    14.277671
# 22281    12.429216
# 22282    14.962914
# 22283          NaN
# 22284          NaN
# 22285    14.616390
# 22286    14.295877
# 22287    12.453909
# 22288          NaN
# 22289          NaN
# 22290    14.165581
# 22291    15.369154
# 22292    12.923912
# 22293          NaN
# 22294    14.301019
# 22295    15.246619
# ...

# %%
# Python program explaining 
# log() function 
import numpy as np 

in_array = [1, 3, 5, 2**8] 
print ("Input array : ", in_array) 

out_array = np.log(in_array) 
print ("Output array : ", out_array) 


print("\nnp.log(4**4) : ", np.log(4**4)) 
print("np.log(2**8) : ", np.log(2**8))
# Out:
# Input array :  [1, 3, 5, 256]
# Output array :  [0.         1.09861229 1.60943791 5.54517744]
#
# np.log(4**4) :  5.545177444479562
# np.log(2**8) :  5.545177444479562
